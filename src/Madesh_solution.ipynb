# %% [markdown]
# # Movie Recommendation System using K-nearest neighbors Model
# ## 1. Data Download and Inspection

# %% [markdown]
# ### 1.1 Import modules

# %%
import json 
import pandas as pd

# %% [markdown]
# ### 1.2 Data download

# %%
movies = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/k-nearest-neighbors-project-tutorial/main/tmdb_5000_movies.csv")
credits = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/k-nearest-neighbors-project-tutorial/main/tmdb_5000_credits.csv")

# %% [markdown]
# ### 1.3 Data inspection

# %%
movies.head().T
# Out:
#                                                                       0  \
# budget                                                        237000000
# genres                [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                    http://www.avatarmovie.com/
# id                                                                19995
# keywords              [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                    en
# original_title                                                   Avatar
# overview              In the 22nd century, a paraplegic Marine is di...
# popularity                                                   150.437577
# production_companies  [{"name": "Ingenious Film Partners", "id": 289...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2009-12-10
# revenue                                                      2787965087
# runtime                                                           162.0
# spoken_languages      [{"iso_639_1": "en", "name": "English"}, {"iso...
# status                                                         Released
# tagline                                     Enter the World of Pandora.
# title                                                            Avatar
# vote_average                                                        7.2
# vote_count                                                        11800
#
#                                                                       1  \
# budget                                                        300000000
# genres                [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# homepage                   http://disney.go.com/disneypictures/pirates/
# id                                                                  285
# keywords              [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# original_language                                                    en
# original_title                 Pirates of the Caribbean: At World's End
# overview              Captain Barbossa, long believed to be dead, ha...
# popularity                                                   139.082615
# production_companies  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2007-05-19
# revenue                                                       961000000
# runtime                                                           169.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                  At the end of the world, the adventure begins.
# title                          Pirates of the Caribbean: At World's End
# vote_average                                                        6.9
# vote_count                                                         4500
#
#                                                                       2  \
# budget                                                        245000000
# genres                [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                    http://www.sonypictures.com/movies/spectre/
# id                                                               206647
# keywords              [{"id": 470, "name": "spy"}, {"id": 818, "name...
# original_language                                                    en
# original_title                                                  Spectre
# overview              A cryptic message from Bond’s past sends him o...
# popularity                                                   107.376788
# production_companies  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# production_countries  [{"iso_3166_1": "GB", "name": "United Kingdom"...
# release_date                                                 2015-10-26
# revenue                                                       880674609
# runtime                                                           148.0
# spoken_languages      [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# status                                                         Released
# tagline                                           A Plan No One Escapes
# title                                                           Spectre
# vote_average                                                        6.3
# vote_count                                                         4466
#
#                                                                       3  \
# budget                                                        250000000
# genres                [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# homepage                             http://www.thedarkknightrises.com/
# id                                                                49026
# keywords              [{"id": 849, "name": "dc comics"}, {"id": 853,...
# original_language                                                    en
# original_title                                    The Dark Knight Rises
# overview              Following the death of District Attorney Harve...
# popularity                                                    112.31295
# production_companies  [{"name": "Legendary Pictures", "id": 923}, {"...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2012-07-16
# revenue                                                      1084939099
# runtime                                                           165.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                                 The Legend Ends
# title                                             The Dark Knight Rises
# vote_average                                                        7.6
# vote_count                                                         9106
#
#                                                                       4
# budget                                                        260000000
# genres                [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                           http://movies.disney.com/john-carter
# id                                                                49529
# keywords              [{"id": 818, "name": "based on novel"}, {"id":...
# original_language                                                    en
# original_title                                              John Carter
# overview              John Carter is a war-weary, former military ca...
# popularity                                                    43.926995
# production_companies        [{"name": "Walt Disney Pictures", "id": 2}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2012-03-07
# revenue                                                       284139100
# runtime                                                           132.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                            Lost in our world, found in another.
# title                                                       John Carter
# vote_average                                                        6.1
# vote_count                                                         2124

# %%
credits.head().T
# Out:
#                                                           0  \
# movie_id                                              19995
# title                                                Avatar
# cast      [{"cast_id": 242, "character": "Jake Sully", "...
# crew      [{"credit_id": "52fe48009251416c750aca23", "de...
#
#                                                           1  \
# movie_id                                                285
# title              Pirates of the Caribbean: At World's End
# cast      [{"cast_id": 4, "character": "Captain Jack Spa...
# crew      [{"credit_id": "52fe4232c3a36847f800b579", "de...
#
#                                                           2  \
# movie_id                                             206647
# title                                               Spectre
# cast      [{"cast_id": 1, "character": "James Bond", "cr...
# crew      [{"credit_id": "54805967c3a36829b5002c41", "de...
#
#                                                           3  \
# movie_id                                              49026
# title                                 The Dark Knight Rises
# cast      [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# crew      [{"credit_id": "52fe4781c3a36847f81398c3", "de...
#
#                                                           4
# movie_id                                              49529
# title                                           John Carter
# cast      [{"cast_id": 5, "character": "John Carter", "c...
# crew      [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %% [markdown]
# - 'Id' from movies df and 'movie_id' from credits df are same, confirming matching data movies in each row! Both dataframes can be joined together for further processing!

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title                 4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
# dtypes: float64(3), int64(4), object(13)
# memory usage: 750.6+ KB

# %% [markdown]
# - Some missing data in columns: homepage, overview, release_date, runtime, tagline
# - Mix of both numerical and categorical features in the dataframe!

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %% [markdown]
# - No missing data!

# %% [markdown]
# ### 1.4 Join two dataframes

# %%
credits.rename({"movie_id": "id"}, axis=1, inplace=True) #renaming the column so we can merge the two datasets 
credits.head().T
# Out:
#                                                        0  \
# id                                                 19995
# title                                             Avatar
# cast   [{"cast_id": 242, "character": "Jake Sully", "...
# crew   [{"credit_id": "52fe48009251416c750aca23", "de...
#
#                                                        1  \
# id                                                   285
# title           Pirates of the Caribbean: At World's End
# cast   [{"cast_id": 4, "character": "Captain Jack Spa...
# crew   [{"credit_id": "52fe4232c3a36847f800b579", "de...
#
#                                                        2  \
# id                                                206647
# title                                            Spectre
# cast   [{"cast_id": 1, "character": "James Bond", "cr...
# crew   [{"credit_id": "54805967c3a36829b5002c41", "de...
#
#                                                        3  \
# id                                                 49026
# title                              The Dark Knight Rises
# cast   [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# crew   [{"credit_id": "52fe4781c3a36847f81398c3", "de...
#
#                                                        4
# id                                                 49529
# title                                        John Carter
# cast   [{"cast_id": 5, "character": "John Carter", "c...
# crew   [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
data_df = pd.merge(movies, credits, on='id', how='outer')
data_df.head().T
# Out:
#                                                                       0  \
# budget                                                          4000000
# genres                [{"id": 80, "name": "Crime"}, {"id": 35, "name...
# homepage                                                            NaN
# id                                                                    5
# keywords              [{"id": 612, "name": "hotel"}, {"id": 613, "na...
# original_language                                                    en
# original_title                                               Four Rooms
# overview              It's Ted the Bellhop's first night on the job....
# popularity                                                     22.87623
# production_companies  [{"name": "Miramax Films", "id": 14}, {"name":...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1995-12-09
# revenue                                                         4300000
# runtime                                                            98.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline               Twelve outrageous guests. Four scandalous requ...
# title_x                                                      Four Rooms
# vote_average                                                        6.5
# vote_count                                                          530
# title_y                                                      Four Rooms
# cast                  [{"cast_id": 42, "character": "Ted the Bellhop...
# crew                  [{"credit_id": "52fe420dc3a36847f800012d", "de...
#
#                                                                       1  \
# budget                                                         11000000
# genres                [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# homepage              http://www.starwars.com/films/star-wars-episod...
# id                                                                   11
# keywords              [{"id": 803, "name": "android"}, {"id": 4270, ...
# original_language                                                    en
# original_title                                                Star Wars
# overview              Princess Leia is captured and held hostage by ...
# popularity                                                   126.393695
# production_companies  [{"name": "Lucasfilm", "id": 1}, {"name": "Twe...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1977-05-25
# revenue                                                       775398007
# runtime                                                           121.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                    A long time ago in a galaxy far, far away...
# title_x                                                       Star Wars
# vote_average                                                        8.1
# vote_count                                                         6624
# title_y                                                       Star Wars
# cast                  [{"cast_id": 3, "character": "Luke Skywalker",...
# crew                  [{"credit_id": "52fe420dc3a36847f8000437", "de...
#
#                                                                       2  \
# budget                                                         94000000
# genres                [{"id": 16, "name": "Animation"}, {"id": 10751...
# homepage                          http://movies.disney.com/finding-nemo
# id                                                                   12
# keywords              [{"id": 494, "name": "father son relationship"...
# original_language                                                    en
# original_title                                             Finding Nemo
# overview              Nemo, an adventurous young clownfish, is unexp...
# popularity                                                    85.688789
# production_companies     [{"name": "Pixar Animation Studios", "id": 3}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2003-05-30
# revenue                                                       940335536
# runtime                                                           100.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline               There are 3.7 trillion fish in the ocean, they...
# title_x                                                    Finding Nemo
# vote_average                                                        7.6
# vote_count                                                         6122
# title_y                                                    Finding Nemo
# cast                  [{"cast_id": 8, "character": "Marlin (voice)",...
# crew                  [{"credit_id": "52fe420ec3a36847f80006b1", "de...
#
#                                                                       3  \
# budget                                                         55000000
# genres                [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# homepage                                                            NaN
# id                                                                   13
# keywords              [{"id": 422, "name": "vietnam veteran"}, {"id"...
# original_language                                                    en
# original_title                                             Forrest Gump
# overview              A man with a low IQ has accomplished great thi...
# popularity                                                   138.133331
# production_companies          [{"name": "Paramount Pictures", "id": 4}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1994-07-06
# revenue                                                       677945399
# runtime                                                           142.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline               The world will never be the same, once you've ...
# title_x                                                    Forrest Gump
# vote_average                                                        8.2
# vote_count                                                         7927
# title_y                                                    Forrest Gump
# cast                  [{"cast_id": 7, "character": "Forrest Gump", "...
# crew                  [{"credit_id": "52fe420ec3a36847f800076b", "de...
#
#                                                                       4
# budget                                                         15000000
# genres                                    [{"id": 18, "name": "Drama"}]
# homepage                                  http://www.dreamworks.com/ab/
# id                                                                   14
# keywords              [{"id": 255, "name": "male nudity"}, {"id": 29...
# original_language                                                    en
# original_title                                          American Beauty
# overview              Lester Burnham, a depressed suburban father in...
# popularity                                                    80.878605
# production_companies  [{"name": "DreamWorks SKG", "id": 27}, {"name"...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1999-09-15
# revenue                                                       356296601
# runtime                                                           122.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                                    Look closer.
# title_x                                                 American Beauty
# vote_average                                                        7.9
# vote_count                                                         3313
# title_y                                                 American Beauty
# cast                  [{"cast_id": 6, "character": "Lester Burnham",...
# crew                  [{"credit_id": "52fe420ec3a36847f8000809", "de...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title_x               4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
#  20  title_y               4803 non-null   object
#  21  cast                  4803 non-null   object
#  22  crew                  4803 non-null   object
# dtypes: float64(3), int64(4), object(16)
# memory usage: 863.2+ KB

# %% [markdown]
# - Merge worked but with 3 features referring to 'movie title'
# - cleanup the movie title issue from the data frame!

# %%
data_df.drop(['title_x', 'title_y'], axis=1, inplace=True)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  vote_average          4803 non-null   float64
#  18  vote_count            4803 non-null   int64
#  19  cast                  4803 non-null   object
#  20  crew                  4803 non-null   object
# dtypes: float64(3), int64(4), object(14)
# memory usage: 788.1+ KB

# %%
data_df.rename({"original_title": "title"}, axis=1, inplace=True)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   title                 4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  vote_average          4803 non-null   float64
#  18  vote_count            4803 non-null   int64
#  19  cast                  4803 non-null   object
#  20  crew                  4803 non-null   object
# dtypes: float64(3), int64(4), object(14)
# memory usage: 788.1+ KB

# %%
data_df['cast']
# Out:
# 0       [{"cast_id": 42, "character": "Ted the Bellhop...
# 1       [{"cast_id": 3, "character": "Luke Skywalker",...
# 2       [{"cast_id": 8, "character": "Marlin (voice)",...
# 3       [{"cast_id": 7, "character": "Forrest Gump", "...
# 4       [{"cast_id": 6, "character": "Lester Burnham",...
#                               ...
# 4798    [{"cast_id": 1, "character": "Dawn", "credit_i...
# 4799    [{"cast_id": 4, "character": "Smith Bhatnagar"...
# 4800    [{"cast_id": 3, "character": "Amber", "credit_...
# 4801                                                   []
# 4802    [{"cast_id": 0, "character": "Narrator", "cred...
# Name: cast, Length: 4803, dtype: object

# %%
data_df['keywords']
# Out:
# 0       [{"id": 612, "name": "hotel"}, {"id": 613, "na...
# 1       [{"id": 803, "name": "android"}, {"id": 4270, ...
# 2       [{"id": 494, "name": "father son relationship"...
# 3       [{"id": 422, "name": "vietnam veteran"}, {"id"...
# 4       [{"id": 255, "name": "male nudity"}, {"id": 29...
#                               ...
# 4798                                                   []
# 4799                                                   []
# 4800    [{"id": 10060, "name": "christian film"}, {"id...
# 4801                                                   []
# 4802    [{"id": 6027, "name": "music"}, {"id": 225822,...
# Name: keywords, Length: 4803, dtype: object

# %%
data_df['genres']
# Out:
# 0       [{"id": 80, "name": "Crime"}, {"id": 35, "name...
# 1       [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 2       [{"id": 16, "name": "Animation"}, {"id": 10751...
# 3       [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4                           [{"id": 18, "name": "Drama"}]
#                               ...
# 4798                       [{"id": 27, "name": "Horror"}]
# 4799    [{"id": 35, "name": "Comedy"}, {"id": 10751, "...
# 4800    [{"id": 53, "name": "Thriller"}, {"id": 18, "n...
# 4801                    [{"id": 10751, "name": "Family"}]
# 4802                  [{"id": 99, "name": "Documentary"}]
# Name: genres, Length: 4803, dtype: object

# %% [markdown]
# ## 2. EDA

# %%
encoded_data_df= data_df.copy()
encoded_data_df.head().T
# Out:
#                                                                       0  \
# budget                                                          4000000
# genres                [{"id": 80, "name": "Crime"}, {"id": 35, "name...
# homepage                                                            NaN
# id                                                                    5
# keywords              [{"id": 612, "name": "hotel"}, {"id": 613, "na...
# original_language                                                    en
# title                                                        Four Rooms
# overview              It's Ted the Bellhop's first night on the job....
# popularity                                                     22.87623
# production_companies  [{"name": "Miramax Films", "id": 14}, {"name":...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1995-12-09
# revenue                                                         4300000
# runtime                                                            98.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline               Twelve outrageous guests. Four scandalous requ...
# vote_average                                                        6.5
# vote_count                                                          530
# cast                  [{"cast_id": 42, "character": "Ted the Bellhop...
# crew                  [{"credit_id": "52fe420dc3a36847f800012d", "de...
#
#                                                                       1  \
# budget                                                         11000000
# genres                [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# homepage              http://www.starwars.com/films/star-wars-episod...
# id                                                                   11
# keywords              [{"id": 803, "name": "android"}, {"id": 4270, ...
# original_language                                                    en
# title                                                         Star Wars
# overview              Princess Leia is captured and held hostage by ...
# popularity                                                   126.393695
# production_companies  [{"name": "Lucasfilm", "id": 1}, {"name": "Twe...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1977-05-25
# revenue                                                       775398007
# runtime                                                           121.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                    A long time ago in a galaxy far, far away...
# vote_average                                                        8.1
# vote_count                                                         6624
# cast                  [{"cast_id": 3, "character": "Luke Skywalker",...
# crew                  [{"credit_id": "52fe420dc3a36847f8000437", "de...
#
#                                                                       2  \
# budget                                                         94000000
# genres                [{"id": 16, "name": "Animation"}, {"id": 10751...
# homepage                          http://movies.disney.com/finding-nemo
# id                                                                   12
# keywords              [{"id": 494, "name": "father son relationship"...
# original_language                                                    en
# title                                                      Finding Nemo
# overview              Nemo, an adventurous young clownfish, is unexp...
# popularity                                                    85.688789
# production_companies     [{"name": "Pixar Animation Studios", "id": 3}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2003-05-30
# revenue                                                       940335536
# runtime                                                           100.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline               There are 3.7 trillion fish in the ocean, they...
# vote_average                                                        7.6
# vote_count                                                         6122
# cast                  [{"cast_id": 8, "character": "Marlin (voice)",...
# crew                  [{"credit_id": "52fe420ec3a36847f80006b1", "de...
#
#                                                                       3  \
# budget                                                         55000000
# genres                [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# homepage                                                            NaN
# id                                                                   13
# keywords              [{"id": 422, "name": "vietnam veteran"}, {"id"...
# original_language                                                    en
# title                                                      Forrest Gump
# overview              A man with a low IQ has accomplished great thi...
# popularity                                                   138.133331
# production_companies          [{"name": "Paramount Pictures", "id": 4}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1994-07-06
# revenue                                                       677945399
# runtime                                                           142.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline               The world will never be the same, once you've ...
# vote_average                                                        8.2
# vote_count                                                         7927
# cast                  [{"cast_id": 7, "character": "Forrest Gump", "...
# crew                  [{"credit_id": "52fe420ec3a36847f800076b", "de...
#
#                                                                       4
# budget                                                         15000000
# genres                                    [{"id": 18, "name": "Drama"}]
# homepage                                  http://www.dreamworks.com/ab/
# id                                                                   14
# keywords              [{"id": 255, "name": "male nudity"}, {"id": 29...
# original_language                                                    en
# title                                                   American Beauty
# overview              Lester Burnham, a depressed suburban father in...
# popularity                                                    80.878605
# production_companies  [{"name": "DreamWorks SKG", "id": 27}, {"name"...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1999-09-15
# revenue                                                       356296601
# runtime                                                           122.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                                    Look closer.
# vote_average                                                        7.9
# vote_count                                                         3313
# cast                  [{"cast_id": 6, "character": "Lester Burnham",...
# crew                  [{"credit_id": "52fe420ec3a36847f8000809", "de...

# %% [markdown]
# ### 2.1 Feature Encoding
# #### 2.1.1 Cleanup JSON formatted data

# %%
encoded_data_df['cast'][0]
# Out:
# '[{"cast_id": 42, "character": "Ted the Bellhop", "credit_id": "52fe420dc3a36847f80001b7", "gender": 2, "id": 3129, "name": "Tim Roth", "order": 0}, {"cast_id": 31, "character": "Man", "credit_id": "52fe420dc3a36847f800018b", "gender": 2, "id": 3131, "name": "Antonio Banderas", "order": 1}, {"cast_id": 29, "character": "Angela", "credit_id": "52fe420dc3a36847f8000183", "gender": 1, "id": 3130, "name": "Jennifer Beals", "order": 2}, {"cast_id": 25, "character": "Elspeth", "credit_id": "52fe420dc3a36847f8000173", "gender": 1, "id": 3125, "name": "Madonna", "order": 3}, {"cast_id": 41, "character": "Margaret", "credit_id": "52fe420dc3a36847f80001b3", "gender": 1, "id": 3141, "name": "Marisa Tomei", "order": 4}, {"cast_id": 43, "character": "Leo", "credit_id": "52fe420dc3a36847f80001bb", "gender": 2, "id": 62, "name": "Bruce Willis", "order": 5}, {"cast_id": 38, "character": "Chester Rush", "credit_id": "52fe420dc3a36847f80001a7", "gender": 2, "id": 138, "name": "Quentin Tarantino", "order": 6}, {"cast_id": 22, "character": "Jezebel", "credit_id": "52fe420dc3a36847f8000167", "gender": 1, "id": 3122, "name": "Sammi Davis", "order": 7}, {"cast_id": 23, "character": "Diana", "credit_id": "52fe420dc3a36847f800016b", "gender": 1, "id": 3123, "name": "Amanda de Cadenet", "order": 8}, {"cast_id": 24, "character": "Athena", "credit_id": "52fe420dc3a36847f800016f", "gender": 1, "id": 3124, "name": "Valeria Golino", "order": 9}, {"cast_id": 27, "character": "Raven", "credit_id": "52fe420dc3a36847f800017b", "gender": 1, "id": 3127, "name": "Lili Taylor", "order": 10}, {"cast_id": 39, "character": "Long Hair Yuppy Scum", "credit_id": "52fe420dc3a36847f80001ab", "gender": 2, "id": 2545, "name": "Lawrence Bender", "order": 11}, {"cast_id": 26, "character": "Eva", "credit_id": "52fe420dc3a36847f8000177", "gender": 1, "id": 3126, "name": "Ione Skye", "order": 12}, {"cast_id": 28, "character": "Kiva", "credit_id": "52fe420dc3a36847f800017f", "gender": 1, "id": 3128, "name": "Alicia Witt", "order": 13}, {"cast_id": 30, "character": "Siegfried", "credit_id": "52fe420dc3a36847f8000187", "gender": 2, "id": 2555, "name": "David Proval", "order": 14}, {"cast_id": 32, "character": "Sarah", "credit_id": "52fe420dc3a36847f800018f", "gender": 1, "id": 3132, "name": "Lana McKissack", "order": 15}, {"cast_id": 34, "character": "Wife", "credit_id": "52fe420dc3a36847f8000197", "gender": 1, "id": 3134, "name": "Tamlyn Tomita", "order": 16}, {"cast_id": 40, "character": "Betty", "credit_id": "52fe420dc3a36847f80001af", "gender": 1, "id": 3138, "name": "Kathy Griffin", "order": 17}, {"cast_id": 37, "character": "Norman", "credit_id": "52fe420dc3a36847f80001a3", "gender": 2, "id": 3137, "name": "Paul Calderon", "order": 18}, {"cast_id": 36, "character": "TV Dancing Girl", "credit_id": "52fe420dc3a36847f800019f", "gender": 1, "id": 3136, "name": "Salma Hayek", "order": 19}, {"cast_id": 33, "character": "Corpse", "credit_id": "52fe420dc3a36847f8000193", "gender": 1, "id": 3133, "name": "Patricia Vonne", "order": 20}, {"cast_id": 35, "character": "Juancho", "credit_id": "52fe420dc3a36847f800019b", "gender": 0, "id": 3135, "name": "Danny Verduzco", "order": 21}, {"cast_id": 44, "character": "Hooker", "credit_id": "52fe420dc3a36847f80001bf", "gender": 0, "id": 37336, "name": "Kimberly Blair", "order": 22}, {"cast_id": 45, "character": "Sam the Bellhop", "credit_id": "52fe420dc3a36847f80001c3", "gender": 2, "id": 3140, "name": "Marc Lawrence", "order": 23}]'

# %%
encoded_data_df['cast']=data_df['cast'].apply(lambda x: [item['name'] for item in json.loads(x)][:3] if pd.notna(x) else None)
encoded_data_df['cast'][0]
# Out:
# ['Tim Roth', 'Antonio Banderas', 'Jennifer Beals']

# %%
encoded_data_df.T
# Out:
#                                                                    0     \
# budget                                                          4000000
# genres                [{"id": 80, "name": "Crime"}, {"id": 35, "name...
# homepage                                                            NaN
# id                                                                    5
# keywords              [{"id": 612, "name": "hotel"}, {"id": 613, "na...
# original_language                                                    en
# title                                                        Four Rooms
# overview              It's Ted the Bellhop's first night on the job....
# popularity                                                     22.87623
# production_companies  [{"name": "Miramax Films", "id": 14}, {"name":...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1995-12-09
# revenue                                                         4300000
# runtime                                                            98.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline               Twelve outrageous guests. Four scandalous requ...
# vote_average                                                        6.5
# vote_count                                                          530
# cast                       [Tim Roth, Antonio Banderas, Jennifer Beals]
# crew                  [{"credit_id": "52fe420dc3a36847f800012d", "de...
#
#                                                                    1     \
# budget                                                         11000000
# genres                [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# homepage              http://www.starwars.com/films/star-wars-episod...
# id                                                                   11
# keywords              [{"id": 803, "name": "android"}, {"id": 4270, ...
# original_language                                                    en
# title                                                         Star Wars
# overview              Princess Leia is captured and held hostage by ...
# popularity                                                   126.393695
# production_companies  [{"name": "Lucasfilm", "id": 1}, {"name": "Twe...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1977-05-25
# revenue                                                       775398007
# runtime                                                           121.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                    A long time ago in a galaxy far, far away...
# vote_average                                                        8.1
# vote_count                                                         6624
# cast                        [Mark Hamill, Harrison Ford, Carrie Fisher]
# crew                  [{"credit_id": "52fe420dc3a36847f8000437", "de...
#
#                                                                    2     \
# budget                                                         94000000
# genres                [{"id": 16, "name": "Animation"}, {"id": 10751...
# homepage                          http://movies.disney.com/finding-nemo
# id                                                                   12
# keywords              [{"id": 494, "name": "father son relationship"...
# original_language                                                    en
# title                                                      Finding Nemo
# overview              Nemo, an adventurous young clownfish, is unexp...
# popularity                                                    85.688789
# production_companies     [{"name": "Pixar Animation Studios", "id": 3}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2003-05-30
# revenue                                                       940335536
# runtime                                                           100.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline               There are 3.7 trillion fish in the ocean, they...
# vote_average                                                        7.6
# vote_count                                                         6122
# cast                  [Albert Brooks, Ellen DeGeneres, Alexander Gould]
# crew                  [{"credit_id": "52fe420ec3a36847f80006b1", "de...
#
#                                                                    3     \
# budget                                                         55000000
# genres                [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# homepage                                                            NaN
# id                                                                   13
# keywords              [{"id": 422, "name": "vietnam veteran"}, {"id"...
# original_language                                                    en
# title                                                      Forrest Gump
# overview              A man with a low IQ has accomplished great thi...
# popularity                                                   138.133331
# production_companies          [{"name": "Paramount Pictures", "id": 4}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1994-07-06
# revenue                                                       677945399
# runtime                                                           142.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline               The world will never be the same, once you've ...
# vote_average                                                        8.2
# vote_count                                                         7927
# cast                             [Tom Hanks, Robin Wright, Gary Sinise]
# crew                  [{"credit_id": "52fe420ec3a36847f800076b", "de...
#
#                                                                    4     \
# budget                                                         15000000
# genres                                    [{"id": 18, "name": "Drama"}]
# homepage                                  http://www.dreamworks.com/ab/
# id                                                                   14
# keywords              [{"id": 255, "name": "male nudity"}, {"id": 29...
# original_language                                                    en
# title                                                   American Beauty
# overview              Lester Burnham, a depressed suburban father in...
# popularity                                                    80.878605
# production_companies  [{"name": "DreamWorks SKG", "id": 27}, {"name"...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1999-09-15
# revenue                                                       356296601
# runtime                                                           122.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                                    Look closer.
# vote_average                                                        7.9
# vote_count                                                         3313
# cast                        [Kevin Spacey, Annette Bening, Thora Birch]
# crew                  [{"credit_id": "52fe420ec3a36847f8000809", "de...
#
#                                                                    5     \
# budget                                                         12800000
# genres                [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# homepage                                                            NaN
# id                                                                   16
# keywords              [{"id": 30, "name": "individual"}, {"id": 246,...
# original_language                                                    en
# title                                                Dancer in the Dark
# overview              Selma, a Czech immigrant on the verge of blind...
# popularity                                                    22.022228
# production_companies  [{"name": "Fine Line Features", "id": 8}, {"na...
# production_countries  [{"iso_3166_1": "AR", "name": "Argentina"}, {"...
# release_date                                                 2000-05-17
# revenue                                                        40031879
# runtime                                                           140.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                     You don't need eyes to see.
# vote_average                                                        7.6
# vote_count                                                          377
# cast                            [Björk, Catherine Deneuve, David Morse]
# crew                  [{"credit_id": "52fe420ec3a36847f8000981", "de...
#
#                                                                    6     \
# budget                                                         90000000
# genres                [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# homepage                                                            NaN
# id                                                                   18
# keywords              [{"id": 402, "name": "clone"}, {"id": 444, "na...
# original_language                                                    en
# title                                                 The Fifth Element
# overview              In 2257, a taxi driver is unintentionally give...
# popularity                                                   109.528572
# production_companies  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# production_countries           [{"iso_3166_1": "FR", "name": "France"}]
# release_date                                                 1997-05-07
# revenue                                                       263920180
# runtime                                                           126.0
# spoken_languages      [{"iso_639_1": "en", "name": "English"}, {"iso...
# status                                                         Released
# tagline                                  There is no future without it.
# vote_average                                                        7.3
# vote_count                                                         3885
# cast                              [Bruce Willis, Gary Oldman, Ian Holm]
# crew                  [{"credit_id": "52fe420fc3a36847f8000c09", "de...
#
#                                                                    7     \
# budget                                                         92620000
# genres                [{"id": 18, "name": "Drama"}, {"id": 878, "nam...
# homepage                                                            NaN
# id                                                                   19
# keywords              [{"id": 312, "name": "man vs machine"}, {"id":...
# original_language                                                    de
# title                                                        Metropolis
# overview              In a futuristic city sharply divided between t...
# popularity                                                    32.351527
# production_companies  [{"name": "Paramount Pictures", "id": 4}, {"na...
# production_countries          [{"iso_3166_1": "DE", "name": "Germany"}]
# release_date                                                 1927-01-10
# revenue                                                          650422
# runtime                                                           153.0
# spoken_languages           [{"iso_639_1": "xx", "name": "No Language"}]
# status                                                         Released
# tagline               There can be no understanding between the hand...
# vote_average                                                        8.0
# vote_count                                                          657
# cast                      [Brigitte Helm, Alfred Abel, Gustav Fröhlich]
# crew                  [{"credit_id": "52fe420fc3a36847f8000c55", "de...
#
#                                                                    8     \
# budget                                                                0
# genres                [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# homepage              http://www.clubcultura.com/clubcine/clubcineas...
# id                                                                   20
# keywords              [{"id": 455, "name": "farewell"}, {"id": 457, ...
# original_language                                                    en
# title                                                My Life Without Me
# overview              A Pedro Almodovar production in which a fatall...
# popularity                                                     7.958831
# production_companies  [{"name": "El Deseo", "id": 49}, {"name": "Mil...
# production_countries  [{"iso_3166_1": "CA", "name": "Canada"}, {"iso...
# release_date                                                 2003-03-07
# revenue                                                         9726954
# runtime                                                           106.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                                             NaN
# vote_average                                                        7.2
# vote_count                                                           77
# cast                     [Sarah Polley, Amanda Plummer, Scott Speedman]
# crew                  [{"credit_id": "52fe420fc3a36847f8000d1d", "de...
#
#                                                                    9     ...  \
# budget                                                        140000000  ...
# genres                [{"id": 12, "name": "Adventure"}, {"id": 14, "...  ...
# homepage              http://disney.go.com/disneyvideos/liveaction/p...  ...
# id                                                                   22  ...
# keywords              [{"id": 911, "name": "exotic island"}, {"id": ...  ...
# original_language                                                    en  ...
# title                 Pirates of the Caribbean: The Curse of the Bla...  ...
# overview              Jack Sparrow, a freewheeling 17th-century pira...  ...
# popularity                                                   271.972889  ...
# production_companies  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...  ...
# release_date                                                 2003-07-09  ...
# revenue                                                       655011224  ...
# runtime                                                           143.0  ...
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]  ...
# status                                                         Released  ...
# tagline                           Prepare to be blown out of the water.  ...
# vote_average                                                        7.5  ...
# vote_count                                                         6985  ...
# cast                        [Johnny Depp, Geoffrey Rush, Orlando Bloom]  ...
# crew                  [{"credit_id": "52fe420fc3a36847f8000f11", "de...  ...
#
#                                                                    4793  \
# budget                                                                0
# genres                                   [{"id": 27, "name": "Horror"}]
# homepage                                                            NaN
# id                                                               396152
# keywords                                                             []
# original_language                                                    en
# title                                                       Restoration
# overview              During home renovations, a young couple releas...
# popularity                                                     2.525569
# production_companies                                                 []
# production_countries                                                 []
# release_date                                                 2016-05-03
# revenue                                                               0
# runtime                                                            90.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                                             NaN
# vote_average                                                        5.3
# vote_count                                                           11
# cast                      [Emily Roya O'Brien, Adrian Gaeta, Zack Ward]
# crew                  [{"credit_id": "572bd470c3a368013d0002b1", "de...
#
#                                                                    4794  \
# budget                                                                0
# genres                                   [{"id": 27, "name": "Horror"}]
# homepage                                                            NaN
# id                                                               402515
# keywords              [{"id": 321, "name": "terror"}, {"id": 8087, "...
# original_language                                                    pt
# title                                                          Solitude
# overview              After finding an old storage locker filled wit...
# popularity                                                     0.018716
# production_companies       [{"name": "Gravitas Ventures", "id": 44632}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2014-10-21
# revenue                                                               0
# runtime                                                            89.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                                             NaN
# vote_average                                                        0.0
# vote_count                                                            0
# cast                  [Armin Habibovich, Victoria Lachelle, Livingst...
# crew                  [{"credit_id": "57edab3b9251416cd600077f", "de...
#
#                                                                    4795  \
# budget                                                                0
# genres                [{"id": 36, "name": "History"}, {"id": 18, "na...
# homepage                                                            NaN
# id                                                               407887
# keywords              [{"id": 10586, "name": "korea"}, {"id": 229851...
# original_language                                                    ko
# title                                                            인천상륙작전
# overview              A squad of soldiers fight in the Korean War's ...
# popularity                                                     6.116436
# production_companies     [{"name": "Taewon Entertainment", "id": 3965}]
# production_countries      [{"iso_3166_1": "KR", "name": "South Korea"}]
# release_date                                                 2016-07-27
# revenue                                                               0
# runtime                                                           110.0
# spoken_languages      [{"iso_639_1": "en", "name": "English"}, {"iso...
# status                                                         Released
# tagline               The Odds Were 5000 to 1 … One was all They Nee...
# vote_average                                                        5.8
# vote_count                                                           29
# cast                          [Lee Jung-jae, Liam Neeson, Lee Beom-soo]
# crew                  [{"credit_id": "5843fb6fc3a3684813007fb4", "de...
#
#                                                                    4796  \
# budget                                                              200
# genres                                    [{"id": 18, "name": "Drama"}]
# homepage                                                            NaN
# id                                                               408429
# keywords                                                             []
# original_language                                                    en
# title                                                    Perfect Cowboy
# overview              Two gay fathers of a straight country western ...
# popularity                                                     0.050978
# production_companies                                                 []
# production_countries                                                 []
# release_date                                                 2014-07-13
# revenue                                                               0
# runtime                                                           109.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                                             NaN
# vote_average                                                        5.0
# vote_count                                                            1
# cast                         [Ken Roht, Jeffrey Watkins, William Nicol]
# crew                  [{"credit_id": "57d568c49251415c1b001ba2", "de...
#
#                                                                    4797  \
# budget                                                        130000000
# genres                [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                                            NaN
# id                                                               417859
# keywords              [{"id": 4414, "name": "adventure"}, {"id": 618...
# original_language                                                    en
# title                                                     Puss in Boots
# overview              Long before he even met Shrek, the notorious f...
# popularity                                                    20.678787
# production_companies                  [{"name": "DreamWorks", "id": 7}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2011-10-28
# revenue                                                       554987477
# runtime                                                            90.0
# spoken_languages      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}, ...
# status                                                         Released
# tagline               Live for danger. Fight for justice. Pray for m...
# vote_average                                                        6.4
# vote_count                                                          451
# cast                  [Antonio Banderas, Salma Hayek, Zach Galifiana...
# crew                  [{"credit_id": "5961020d9251410a590bd228", "de...
#
#                                                                    4798  \
# budget                                                                0
# genres                                   [{"id": 27, "name": "Horror"}]
# homepage                                                            NaN
# id                                                               426067
# keywords                                                             []
# original_language                                                    en
# title                                                  Midnight Cabaret
# overview              A Broadway producer puts on a play with a Devi...
# popularity                                                     0.001389
# production_companies                                                 []
# production_countries                                                 []
# release_date                                                 1990-01-01
# revenue                                                               0
# runtime                                                            94.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                             The hot spot where Satan's waitin'.
# vote_average                                                        0.0
# vote_count                                                            0
# cast                  [Lisa Hart Carroll, Michael Des Barres, Paul D...
# crew                  [{"credit_id": "582a4cdb9251417b1803dd47", "de...
#
#                                                                    4799  \
# budget                                                                0
# genres                [{"id": 35, "name": "Comedy"}, {"id": 10751, "...
# homepage                             http://www.growingupsmithmovie.com
# id                                                               426469
# keywords                                                             []
# original_language                                                    en
# title                                                  Growing Up Smith
# overview              In 1979, an Indian family moves to America wit...
# popularity                                                      0.71087
# production_companies                                                 []
# production_countries                                                 []
# release_date                                                 2017-02-03
# revenue                                                               0
# runtime                                                           102.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                        It’s better to stand out than to fit in.
# vote_average                                                        7.4
# vote_count                                                            7
# cast                       [Roni Akurati, Brighton Sharbino, Jason Lee]
# crew                  [{"credit_id": "582e0bdfc3a368772600b6c1", "de...
#
#                                                                    4800  \
# budget                                                                0
# genres                [{"id": 53, "name": "Thriller"}, {"id": 18, "n...
# homepage                                                            NaN
# id                                                               433715
# keywords              [{"id": 10060, "name": "christian film"}, {"id...
# original_language                                                    en
# title                                                            8 Days
# overview              After sneaking to a party with her friends, 16...
# popularity                                                     0.015295
# production_companies     [{"name": "After Eden Pictures", "id": 85248}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2014-06-15
# revenue                                                               0
# runtime                                                            90.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                        She never knew it could happen to her...
# vote_average                                                        0.0
# vote_count                                                            0
# cast                      [Nicole Smolen, Kim Baldwin, Ariana Stephens]
# crew                  [{"credit_id": "58713acfc3a3684f0a00a9ac", "de...
#
#                                                                    4801  \
# budget                                                                0
# genres                                [{"id": 10751, "name": "Family"}]
# homepage                                                            NaN
# id                                                               447027
# keywords                                                             []
# original_language                                                    en
# title                                                   Running Forever
# overview              After being estranged since her mother's death...
# popularity                                                     0.028756
# production_companies    [{"name": "New Kingdom Pictures", "id": 41671}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2015-10-27
# revenue                                                               0
# runtime                                                            88.0
# spoken_languages                                                     []
# status                                                         Released
# tagline                                                             NaN
# vote_average                                                        0.0
# vote_count                                                            0
# cast                                                                 []
# crew                                                                 []
#
#                                                                    4802
# budget                                                                2
# genres                              [{"id": 99, "name": "Documentary"}]
# homepage                                                            NaN
# id                                                               459488
# keywords              [{"id": 6027, "name": "music"}, {"id": 225822,...
# original_language                                                    en
# title                                       To Be Frank, Sinatra at 100
# overview                                                            NaN
# popularity                                                     0.050625
# production_companies   [{"name": "Eyeline Entertainment", "id": 60343}]
# production_countries   [{"iso_3166_1": "GB", "name": "United Kingdom"}]
# release_date                                                 2015-12-12
# revenue                                                               0
# runtime                                                             NaN
# spoken_languages                                                     []
# status                                                         Released
# tagline                                                             NaN
# vote_average                                                        0.0
# vote_count                                                            0
# cast                                                  [Tony Oppedisano]
# crew                  [{"credit_id": "592b25e4c3a368783e065a2f", "de...
#
# [21 rows x 4803 columns]

# %%
encoded_data_df['genres'][0]
# Out:
# '[{"id": 80, "name": "Crime"}, {"id": 35, "name": "Comedy"}]'

# %%
encoded_data_df['genres']=data_df['genres'].apply( lambda x: [item['name'] for item in json.loads(x)][:3] if pd.notna(x) else None)
encoded_data_df['genres'][0]
# Out:
# ['Crime', 'Comedy']

# %%
encoded_data_df.T
# Out:
#                                                                    0     \
# budget                                                          4000000
# genres                                                  [Crime, Comedy]
# homepage                                                            NaN
# id                                                                    5
# keywords              [{"id": 612, "name": "hotel"}, {"id": 613, "na...
# original_language                                                    en
# title                                                        Four Rooms
# overview              It's Ted the Bellhop's first night on the job....
# popularity                                                     22.87623
# production_companies  [{"name": "Miramax Films", "id": 14}, {"name":...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1995-12-09
# revenue                                                         4300000
# runtime                                                            98.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline               Twelve outrageous guests. Four scandalous requ...
# vote_average                                                        6.5
# vote_count                                                          530
# cast                       [Tim Roth, Antonio Banderas, Jennifer Beals]
# crew                  [{"credit_id": "52fe420dc3a36847f800012d", "de...
#
#                                                                    1     \
# budget                                                         11000000
# genres                             [Adventure, Action, Science Fiction]
# homepage              http://www.starwars.com/films/star-wars-episod...
# id                                                                   11
# keywords              [{"id": 803, "name": "android"}, {"id": 4270, ...
# original_language                                                    en
# title                                                         Star Wars
# overview              Princess Leia is captured and held hostage by ...
# popularity                                                   126.393695
# production_companies  [{"name": "Lucasfilm", "id": 1}, {"name": "Twe...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1977-05-25
# revenue                                                       775398007
# runtime                                                           121.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                    A long time ago in a galaxy far, far away...
# vote_average                                                        8.1
# vote_count                                                         6624
# cast                        [Mark Hamill, Harrison Ford, Carrie Fisher]
# crew                  [{"credit_id": "52fe420dc3a36847f8000437", "de...
#
#                                                                    2     \
# budget                                                         94000000
# genres                                              [Animation, Family]
# homepage                          http://movies.disney.com/finding-nemo
# id                                                                   12
# keywords              [{"id": 494, "name": "father son relationship"...
# original_language                                                    en
# title                                                      Finding Nemo
# overview              Nemo, an adventurous young clownfish, is unexp...
# popularity                                                    85.688789
# production_companies     [{"name": "Pixar Animation Studios", "id": 3}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2003-05-30
# revenue                                                       940335536
# runtime                                                           100.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline               There are 3.7 trillion fish in the ocean, they...
# vote_average                                                        7.6
# vote_count                                                         6122
# cast                  [Albert Brooks, Ellen DeGeneres, Alexander Gould]
# crew                  [{"credit_id": "52fe420ec3a36847f80006b1", "de...
#
#                                                                    3     \
# budget                                                         55000000
# genres                                         [Comedy, Drama, Romance]
# homepage                                                            NaN
# id                                                                   13
# keywords              [{"id": 422, "name": "vietnam veteran"}, {"id"...
# original_language                                                    en
# title                                                      Forrest Gump
# overview              A man with a low IQ has accomplished great thi...
# popularity                                                   138.133331
# production_companies          [{"name": "Paramount Pictures", "id": 4}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1994-07-06
# revenue                                                       677945399
# runtime                                                           142.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline               The world will never be the same, once you've ...
# vote_average                                                        8.2
# vote_count                                                         7927
# cast                             [Tom Hanks, Robin Wright, Gary Sinise]
# crew                  [{"credit_id": "52fe420ec3a36847f800076b", "de...
#
#                                                                    4     \
# budget                                                         15000000
# genres                                                          [Drama]
# homepage                                  http://www.dreamworks.com/ab/
# id                                                                   14
# keywords              [{"id": 255, "name": "male nudity"}, {"id": 29...
# original_language                                                    en
# title                                                   American Beauty
# overview              Lester Burnham, a depressed suburban father in...
# popularity                                                    80.878605
# production_companies  [{"name": "DreamWorks SKG", "id": 27}, {"name"...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1999-09-15
# revenue                                                       356296601
# runtime                                                           122.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                                    Look closer.
# vote_average                                                        7.9
# vote_count                                                         3313
# cast                        [Kevin Spacey, Annette Bening, Thora Birch]
# crew                  [{"credit_id": "52fe420ec3a36847f8000809", "de...
#
#                                                                    5     \
# budget                                                         12800000
# genres                                            [Drama, Crime, Music]
# homepage                                                            NaN
# id                                                                   16
# keywords              [{"id": 30, "name": "individual"}, {"id": 246,...
# original_language                                                    en
# title                                                Dancer in the Dark
# overview              Selma, a Czech immigrant on the verge of blind...
# popularity                                                    22.022228
# production_companies  [{"name": "Fine Line Features", "id": 8}, {"na...
# production_countries  [{"iso_3166_1": "AR", "name": "Argentina"}, {"...
# release_date                                                 2000-05-17
# revenue                                                        40031879
# runtime                                                           140.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                     You don't need eyes to see.
# vote_average                                                        7.6
# vote_count                                                          377
# cast                            [Björk, Catherine Deneuve, David Morse]
# crew                  [{"credit_id": "52fe420ec3a36847f8000981", "de...
#
#                                                                    6     \
# budget                                                         90000000
# genres                                     [Adventure, Fantasy, Action]
# homepage                                                            NaN
# id                                                                   18
# keywords              [{"id": 402, "name": "clone"}, {"id": 444, "na...
# original_language                                                    en
# title                                                 The Fifth Element
# overview              In 2257, a taxi driver is unintentionally give...
# popularity                                                   109.528572
# production_companies  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# production_countries           [{"iso_3166_1": "FR", "name": "France"}]
# release_date                                                 1997-05-07
# revenue                                                       263920180
# runtime                                                           126.0
# spoken_languages      [{"iso_639_1": "en", "name": "English"}, {"iso...
# status                                                         Released
# tagline                                  There is no future without it.
# vote_average                                                        7.3
# vote_count                                                         3885
# cast                              [Bruce Willis, Gary Oldman, Ian Holm]
# crew                  [{"credit_id": "52fe420fc3a36847f8000c09", "de...
#
#                                                                    7     \
# budget                                                         92620000
# genres                                         [Drama, Science Fiction]
# homepage                                                            NaN
# id                                                                   19
# keywords              [{"id": 312, "name": "man vs machine"}, {"id":...
# original_language                                                    de
# title                                                        Metropolis
# overview              In a futuristic city sharply divided between t...
# popularity                                                    32.351527
# production_companies  [{"name": "Paramount Pictures", "id": 4}, {"na...
# production_countries          [{"iso_3166_1": "DE", "name": "Germany"}]
# release_date                                                 1927-01-10
# revenue                                                          650422
# runtime                                                           153.0
# spoken_languages           [{"iso_639_1": "xx", "name": "No Language"}]
# status                                                         Released
# tagline               There can be no understanding between the hand...
# vote_average                                                        8.0
# vote_count                                                          657
# cast                      [Brigitte Helm, Alfred Abel, Gustav Fröhlich]
# crew                  [{"credit_id": "52fe420fc3a36847f8000c55", "de...
#
#                                                                    8     \
# budget                                                                0
# genres                                                 [Drama, Romance]
# homepage              http://www.clubcultura.com/clubcine/clubcineas...
# id                                                                   20
# keywords              [{"id": 455, "name": "farewell"}, {"id": 457, ...
# original_language                                                    en
# title                                                My Life Without Me
# overview              A Pedro Almodovar production in which a fatall...
# popularity                                                     7.958831
# production_companies  [{"name": "El Deseo", "id": 49}, {"name": "Mil...
# production_countries  [{"iso_3166_1": "CA", "name": "Canada"}, {"iso...
# release_date                                                 2003-03-07
# revenue                                                         9726954
# runtime                                                           106.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                                             NaN
# vote_average                                                        7.2
# vote_count                                                           77
# cast                     [Sarah Polley, Amanda Plummer, Scott Speedman]
# crew                  [{"credit_id": "52fe420fc3a36847f8000d1d", "de...
#
#                                                                    9     ...  \
# budget                                                        140000000  ...
# genres                                     [Adventure, Fantasy, Action]  ...
# homepage              http://disney.go.com/disneyvideos/liveaction/p...  ...
# id                                                                   22  ...
# keywords              [{"id": 911, "name": "exotic island"}, {"id": ...  ...
# original_language                                                    en  ...
# title                 Pirates of the Caribbean: The Curse of the Bla...  ...
# overview              Jack Sparrow, a freewheeling 17th-century pira...  ...
# popularity                                                   271.972889  ...
# production_companies  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...  ...
# release_date                                                 2003-07-09  ...
# revenue                                                       655011224  ...
# runtime                                                           143.0  ...
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]  ...
# status                                                         Released  ...
# tagline                           Prepare to be blown out of the water.  ...
# vote_average                                                        7.5  ...
# vote_count                                                         6985  ...
# cast                        [Johnny Depp, Geoffrey Rush, Orlando Bloom]  ...
# crew                  [{"credit_id": "52fe420fc3a36847f8000f11", "de...  ...
#
#                                                                    4793  \
# budget                                                                0
# genres                                                         [Horror]
# homepage                                                            NaN
# id                                                               396152
# keywords                                                             []
# original_language                                                    en
# title                                                       Restoration
# overview              During home renovations, a young couple releas...
# popularity                                                     2.525569
# production_companies                                                 []
# production_countries                                                 []
# release_date                                                 2016-05-03
# revenue                                                               0
# runtime                                                            90.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                                             NaN
# vote_average                                                        5.3
# vote_count                                                           11
# cast                      [Emily Roya O'Brien, Adrian Gaeta, Zack Ward]
# crew                  [{"credit_id": "572bd470c3a368013d0002b1", "de...
#
#                                                                    4794  \
# budget                                                                0
# genres                                                         [Horror]
# homepage                                                            NaN
# id                                                               402515
# keywords              [{"id": 321, "name": "terror"}, {"id": 8087, "...
# original_language                                                    pt
# title                                                          Solitude
# overview              After finding an old storage locker filled wit...
# popularity                                                     0.018716
# production_companies       [{"name": "Gravitas Ventures", "id": 44632}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2014-10-21
# revenue                                                               0
# runtime                                                            89.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                                             NaN
# vote_average                                                        0.0
# vote_count                                                            0
# cast                  [Armin Habibovich, Victoria Lachelle, Livingst...
# crew                  [{"credit_id": "57edab3b9251416cd600077f", "de...
#
#                                                                    4795  \
# budget                                                                0
# genres                                            [History, Drama, War]
# homepage                                                            NaN
# id                                                               407887
# keywords              [{"id": 10586, "name": "korea"}, {"id": 229851...
# original_language                                                    ko
# title                                                            인천상륙작전
# overview              A squad of soldiers fight in the Korean War's ...
# popularity                                                     6.116436
# production_companies     [{"name": "Taewon Entertainment", "id": 3965}]
# production_countries      [{"iso_3166_1": "KR", "name": "South Korea"}]
# release_date                                                 2016-07-27
# revenue                                                               0
# runtime                                                           110.0
# spoken_languages      [{"iso_639_1": "en", "name": "English"}, {"iso...
# status                                                         Released
# tagline               The Odds Were 5000 to 1 … One was all They Nee...
# vote_average                                                        5.8
# vote_count                                                           29
# cast                          [Lee Jung-jae, Liam Neeson, Lee Beom-soo]
# crew                  [{"credit_id": "5843fb6fc3a3684813007fb4", "de...
#
#                                                                    4796  \
# budget                                                              200
# genres                                                          [Drama]
# homepage                                                            NaN
# id                                                               408429
# keywords                                                             []
# original_language                                                    en
# title                                                    Perfect Cowboy
# overview              Two gay fathers of a straight country western ...
# popularity                                                     0.050978
# production_companies                                                 []
# production_countries                                                 []
# release_date                                                 2014-07-13
# revenue                                                               0
# runtime                                                           109.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                                                             NaN
# vote_average                                                        5.0
# vote_count                                                            1
# cast                         [Ken Roht, Jeffrey Watkins, William Nicol]
# crew                  [{"credit_id": "57d568c49251415c1b001ba2", "de...
#
#                                                                    4797  \
# budget                                                        130000000
# genres                                   [Action, Adventure, Animation]
# homepage                                                            NaN
# id                                                               417859
# keywords              [{"id": 4414, "name": "adventure"}, {"id": 618...
# original_language                                                    en
# title                                                     Puss in Boots
# overview              Long before he even met Shrek, the notorious f...
# popularity                                                    20.678787
# production_companies                  [{"name": "DreamWorks", "id": 7}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2011-10-28
# revenue                                                       554987477
# runtime                                                            90.0
# spoken_languages      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}, ...
# status                                                         Released
# tagline               Live for danger. Fight for justice. Pray for m...
# vote_average                                                        6.4
# vote_count                                                          451
# cast                  [Antonio Banderas, Salma Hayek, Zach Galifiana...
# crew                  [{"credit_id": "5961020d9251410a590bd228", "de...
#
#                                                                    4798  \
# budget                                                                0
# genres                                                         [Horror]
# homepage                                                            NaN
# id                                                               426067
# keywords                                                             []
# original_language                                                    en
# title                                                  Midnight Cabaret
# overview              A Broadway producer puts on a play with a Devi...
# popularity                                                     0.001389
# production_companies                                                 []
# production_countries                                                 []
# release_date                                                 1990-01-01
# revenue                                                               0
# runtime                                                            94.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                             The hot spot where Satan's waitin'.
# vote_average                                                        0.0
# vote_count                                                            0
# cast                  [Lisa Hart Carroll, Michael Des Barres, Paul D...
# crew                  [{"credit_id": "582a4cdb9251417b1803dd47", "de...
#
#                                                                    4799  \
# budget                                                                0
# genres                                          [Comedy, Family, Drama]
# homepage                             http://www.growingupsmithmovie.com
# id                                                               426469
# keywords                                                             []
# original_language                                                    en
# title                                                  Growing Up Smith
# overview              In 1979, an Indian family moves to America wit...
# popularity                                                      0.71087
# production_companies                                                 []
# production_countries                                                 []
# release_date                                                 2017-02-03
# revenue                                                               0
# runtime                                                           102.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                        It’s better to stand out than to fit in.
# vote_average                                                        7.4
# vote_count                                                            7
# cast                       [Roni Akurati, Brighton Sharbino, Jason Lee]
# crew                  [{"credit_id": "582e0bdfc3a368772600b6c1", "de...
#
#                                                                    4800  \
# budget                                                                0
# genres                                                [Thriller, Drama]
# homepage                                                            NaN
# id                                                               433715
# keywords              [{"id": 10060, "name": "christian film"}, {"id...
# original_language                                                    en
# title                                                            8 Days
# overview              After sneaking to a party with her friends, 16...
# popularity                                                     0.015295
# production_companies     [{"name": "After Eden Pictures", "id": 85248}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2014-06-15
# revenue                                                               0
# runtime                                                            90.0
# spoken_languages               [{"iso_639_1": "en", "name": "English"}]
# status                                                         Released
# tagline                        She never knew it could happen to her...
# vote_average                                                        0.0
# vote_count                                                            0
# cast                      [Nicole Smolen, Kim Baldwin, Ariana Stephens]
# crew                  [{"credit_id": "58713acfc3a3684f0a00a9ac", "de...
#
#                                                                    4801  \
# budget                                                                0
# genres                                                         [Family]
# homepage                                                            NaN
# id                                                               447027
# keywords                                                             []
# original_language                                                    en
# title                                                   Running Forever
# overview              After being estranged since her mother's death...
# popularity                                                     0.028756
# production_companies    [{"name": "New Kingdom Pictures", "id": 41671}]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2015-10-27
# revenue                                                               0
# runtime                                                            88.0
# spoken_languages                                                     []
# status                                                         Released
# tagline                                                             NaN
# vote_average                                                        0.0
# vote_count                                                            0
# cast                                                                 []
# crew                                                                 []
#
#                                                                    4802
# budget                                                                2
# genres                                                    [Documentary]
# homepage                                                            NaN
# id                                                               459488
# keywords              [{"id": 6027, "name": "music"}, {"id": 225822,...
# original_language                                                    en
# title                                       To Be Frank, Sinatra at 100
# overview                                                            NaN
# popularity                                                     0.050625
# production_companies   [{"name": "Eyeline Entertainment", "id": 60343}]
# production_countries   [{"iso_3166_1": "GB", "name": "United Kingdom"}]
# release_date                                                 2015-12-12
# revenue                                                               0
# runtime                                                             NaN
# spoken_languages                                                     []
# status                                                         Released
# tagline                                                             NaN
# vote_average                                                        0.0
# vote_count                                                            0
# cast                                                  [Tony Oppedisano]
# crew                  [{"credit_id": "592b25e4c3a368783e065a2f", "de...
#
# [21 rows x 4803 columns]

# %%
encoded_data_df['keywords'][0]
# Out:
# '[{"id": 612, "name": "hotel"}, {"id": 613, "name": "new year\'s eve"}, {"id": 616, "name": "witch"}, {"id": 622, "name": "bet"}, {"id": 922, "name": "hotel room"}, {"id": 2700, "name": "sperm"}, {"id": 12670, "name": "los angeles"}, {"id": 160488, "name": "hoodlum"}, {"id": 187056, "name": "woman director"}, {"id": 198129, "name": "episode film"}]'

# %%
encoded_data_df['keywords'] =data_df['keywords'].apply(lambda x: [item['name'] for item in json.loads(x)][:3] if pd.notna(x) else 'none')
encoded_data_df['keywords'][0]
# Out:
# ['hotel', "new year's eve", 'witch']

# %%
encoded_data_df['production_companies'][0]
# Out:
# '[{"name": "Miramax Films", "id": 14}, {"name": "A Band Apart", "id": 59}]'

# %%
encoded_data_df['production_companies'] =data_df['production_companies'].apply(lambda x: [item['name'] for item in json.loads(x)][:3] if pd.notna(x) else 'none')
encoded_data_df['production_companies'][0]
# Out:
# ['Miramax Films', 'A Band Apart']

# %%
encoded_data_df['spoken_languages'][0]
# Out:
# '[{"iso_639_1": "en", "name": "English"}]'

# %%
encoded_data_df['spoken_languages'] = data_df['spoken_languages'].apply(lambda x: [item['name'] for item in json.loads(x)][:3] if pd.notna(x) else 'none')
encoded_data_df['spoken_languages'][0]
# Out:
# ['English']

# %%
encoded_data_df['crew'][0]
# Out:
# '[{"credit_id": "52fe420dc3a36847f800012d", "department": "Directing", "gender": 1, "id": 3110, "job": "Director", "name": "Allison Anders"}, {"credit_id": "52fe420dc3a36847f80001c9", "department": "Writing", "gender": 1, "id": 3110, "job": "Writer", "name": "Allison Anders"}, {"credit_id": "52fe420dc3a36847f8000133", "department": "Directing", "gender": 2, "id": 3111, "job": "Director", "name": "Alexandre Rockwell"}, {"credit_id": "52fe420dc3a36847f8000151", "department": "Production", "gender": 2, "id": 3111, "job": "Executive Producer", "name": "Alexandre Rockwell"}, {"credit_id": "52fe420dc3a36847f80001cf", "department": "Writing", "gender": 2, "id": 3111, "job": "Writer", "name": "Alexandre Rockwell"}, {"credit_id": "52fe420dc3a36847f8000139", "department": "Directing", "gender": 0, "id": 2294, "job": "Director", "name": "Robert Rodriguez"}, {"credit_id": "52fe420dc3a36847f80001d5", "department": "Writing", "gender": 0, "id": 2294, "job": "Writer", "name": "Robert Rodriguez"}, {"credit_id": "52fe420dc3a36847f800020b", "department": "Editing", "gender": 0, "id": 2294, "job": "Editor", "name": "Robert Rodriguez"}, {"credit_id": "52fe420dc3a36847f800013f", "department": "Directing", "gender": 2, "id": 138, "job": "Director", "name": "Quentin Tarantino"}, {"credit_id": "52fe420dc3a36847f800014b", "department": "Production", "gender": 2, "id": 138, "job": "Executive Producer", "name": "Quentin Tarantino"}, {"credit_id": "52fe420dc3a36847f80001db", "department": "Writing", "gender": 2, "id": 138, "job": "Writer", "name": "Quentin Tarantino"}, {"credit_id": "52fe420dc3a36847f800011b", "department": "Sound", "gender": 0, "id": 3116, "job": "Original Music Composer", "name": "Combustible Edison"}, {"credit_id": "52fe420dc3a36847f8000121", "department": "Art", "gender": 2, "id": 3117, "job": "Production Design", "name": "Gary Frutkoff"}, {"credit_id": "52fe420dc3a36847f8000127", "department": "Sound", "gender": 0, "id": 3119, "job": "Sound Designer", "name": "Lance Brown"}, {"credit_id": "52fe420dc3a36847f8000145", "department": "Production", "gender": 2, "id": 2545, "job": "Producer", "name": "Lawrence Bender"}, {"credit_id": "557ddf5dc3a36821930003fa", "department": "Production", "gender": 0, "id": 37333, "job": "Co-Producer", "name": "Heidi Vogel"}, {"credit_id": "557ddf469251410a2f000305", "department": "Production", "gender": 2, "id": 37334, "job": "Co-Producer", "name": "Paul Hellerman"}, {"credit_id": "59a176c2c3a368478f02876d", "department": "Production", "gender": 2, "id": 37334, "job": "Production Manager", "name": "Paul Hellerman"}, {"credit_id": "557ddf50c3a368219c000320", "department": "Production", "gender": 0, "id": 37335, "job": "Co-Producer", "name": "Scott Lambert"}, {"credit_id": "52fe420dc3a36847f8000157", "department": "Production", "gender": 2, "id": 3118, "job": "Casting", "name": "Russell Gray"}, {"credit_id": "52fe420dc3a36847f800015d", "department": "Art", "gender": 2, "id": 11423, "job": "Art Direction", "name": "Mayne Berke"}, {"credit_id": "52fe420dc3a36847f8000163", "department": "Art", "gender": 1, "id": 9042, "job": "Set Decoration", "name": "Sara Andrews"}, {"credit_id": "52fe420dc3a36847f8000205", "department": "Editing", "gender": 1, "id": 156, "job": "Editor", "name": "Sally Menke"}, {"credit_id": "52fe420dc3a36847f80001e7", "department": "Camera", "gender": 2, "id": 3113, "job": "Director of Photography", "name": "Guillermo Navarro"}, {"credit_id": "52fe420dc3a36847f80001f3", "department": "Camera", "gender": 2, "id": 3115, "job": "Director of Photography", "name": "Andrzej Sekula"}, {"credit_id": "5636073cc3a3681b52019f3b", "department": "Sound", "gender": 0, "id": 6940, "job": "Music Supervisor", "name": "Karyn Rachtman"}, {"credit_id": "52fe420dc3a36847f80001ff", "department": "Editing", "gender": 0, "id": 3121, "job": "Editor", "name": "Elena Maganini"}, {"credit_id": "52fe420dc3a36847f80001ed", "department": "Camera", "gender": 2, "id": 3114, "job": "Director of Photography", "name": "Phil  ...

# %%
encoded_data_df['crew'] = data_df['crew'].apply(lambda x: [item['name'] for item in json.loads(x)][:3] if pd.notna(x) else 'none')
encoded_data_df['crew'][0]
# Out:
# ['Allison Anders', 'Allison Anders', 'Alexandre Rockwell']

# %%
encoded_data_df.head().T
# Out:
#                                                                       0  \
# budget                                                          4000000
# genres                                                  [Crime, Comedy]
# homepage                                                            NaN
# id                                                                    5
# keywords                                 [hotel, new year's eve, witch]
# original_language                                                    en
# title                                                        Four Rooms
# overview              It's Ted the Bellhop's first night on the job....
# popularity                                                     22.87623
# production_companies                      [Miramax Films, A Band Apart]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1995-12-09
# revenue                                                         4300000
# runtime                                                            98.0
# spoken_languages                                              [English]
# status                                                         Released
# tagline               Twelve outrageous guests. Four scandalous requ...
# vote_average                                                        6.5
# vote_count                                                          530
# cast                       [Tim Roth, Antonio Banderas, Jennifer Beals]
# crew                  [Allison Anders, Allison Anders, Alexandre Roc...
#
#                                                                       1  \
# budget                                                         11000000
# genres                             [Adventure, Action, Science Fiction]
# homepage              http://www.starwars.com/films/star-wars-episod...
# id                                                                   11
# keywords                                      [android, galaxy, hermit]
# original_language                                                    en
# title                                                         Star Wars
# overview              Princess Leia is captured and held hostage by ...
# popularity                                                   126.393695
# production_companies  [Lucasfilm, Twentieth Century Fox Film Corpora...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1977-05-25
# revenue                                                       775398007
# runtime                                                           121.0
# spoken_languages                                              [English]
# status                                                         Released
# tagline                    A long time ago in a galaxy far, far away...
# vote_average                                                        8.1
# vote_count                                                         6624
# cast                        [Mark Hamill, Harrison Ford, Carrie Fisher]
# crew                         [George Lucas, George Lucas, George Lucas]
#
#                                                                       2  \
# budget                                                         94000000
# genres                                              [Animation, Family]
# homepage                          http://movies.disney.com/finding-nemo
# id                                                                   12
# keywords                  [father son relationship, harbor, underwater]
# original_language                                                    en
# title                                                      Finding Nemo
# overview              Nemo, an adventurous young clownfish, is unexp...
# popularity                                                    85.688789
# production_companies                          [Pixar Animation Studios]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2003-05-30
# revenue                                                       940335536
# runtime                                                           100.0
# spoken_languages                                              [English]
# status                                                         Released
# tagline               There are 3.7 trillion fish in the ocean, they...
# vote_average                                                        7.6
# vote_count                                                         6122
# cast                  [Albert Brooks, Ellen DeGeneres, Alexander Gould]
# crew                   [Andrew Stanton, Andrew Stanton, Andrew Stanton]
#
#                                                                       3  \
# budget                                                         55000000
# genres                                         [Comedy, Drama, Romance]
# homepage                                                            NaN
# id                                                                   13
# keywords                   [vietnam veteran, hippie, mentally disabled]
# original_language                                                    en
# title                                                      Forrest Gump
# overview              A man with a low IQ has accomplished great thi...
# popularity                                                   138.133331
# production_companies                               [Paramount Pictures]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1994-07-06
# revenue                                                       677945399
# runtime                                                           142.0
# spoken_languages                                              [English]
# status                                                         Released
# tagline               The world will never be the same, once you've ...
# vote_average                                                        8.2
# vote_count                                                         7927
# cast                             [Tom Hanks, Robin Wright, Gary Sinise]
# crew                   [Alan Silvestri, Robert Zemeckis, Winston Groom]
#
#                                                                       4
# budget                                                         15000000
# genres                                                          [Drama]
# homepage                                  http://www.dreamworks.com/ab/
# id                                                                   14
# keywords                         [male nudity, female nudity, adultery]
# original_language                                                    en
# title                                                   American Beauty
# overview              Lester Burnham, a depressed suburban father in...
# popularity                                                    80.878605
# production_companies              [DreamWorks SKG, Jinks/Cohen Company]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1999-09-15
# revenue                                                       356296601
# runtime                                                           122.0
# spoken_languages                                              [English]
# status                                                         Released
# tagline                                                    Look closer.
# vote_average                                                        7.9
# vote_count                                                         3313
# cast                        [Kevin Spacey, Annette Bening, Thora Birch]
# crew                             [Thomas Newman, Sam Mendes, Alan Ball]

# %% [markdown]
# #### 2.1.2 convert 'Overview' feature to a list

# %%
encoded_data_df['overview']=data_df['overview'].apply(lambda x: [x if pd.notna(x) else 'none'])
encoded_data_df['overview'][0]
# Out:
# ["It's Ted the Bellhop's first night on the job...and the hotel's very unusual guests are about to place him in some outrageous predicaments. It seems that this evening's room service is serving up one unbelievable happening after another."]

# %%
encoded_data_df.head(3).T
# Out:
#                                                                       0  \
# budget                                                          4000000
# genres                                                  [Crime, Comedy]
# homepage                                                            NaN
# id                                                                    5
# keywords                                 [hotel, new year's eve, witch]
# original_language                                                    en
# title                                                        Four Rooms
# overview              [It's Ted the Bellhop's first night on the job...
# popularity                                                     22.87623
# production_companies                      [Miramax Films, A Band Apart]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1995-12-09
# revenue                                                         4300000
# runtime                                                            98.0
# spoken_languages                                              [English]
# status                                                         Released
# tagline               Twelve outrageous guests. Four scandalous requ...
# vote_average                                                        6.5
# vote_count                                                          530
# cast                       [Tim Roth, Antonio Banderas, Jennifer Beals]
# crew                  [Allison Anders, Allison Anders, Alexandre Roc...
#
#                                                                       1  \
# budget                                                         11000000
# genres                             [Adventure, Action, Science Fiction]
# homepage              http://www.starwars.com/films/star-wars-episod...
# id                                                                   11
# keywords                                      [android, galaxy, hermit]
# original_language                                                    en
# title                                                         Star Wars
# overview              [Princess Leia is captured and held hostage by...
# popularity                                                   126.393695
# production_companies  [Lucasfilm, Twentieth Century Fox Film Corpora...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 1977-05-25
# revenue                                                       775398007
# runtime                                                           121.0
# spoken_languages                                              [English]
# status                                                         Released
# tagline                    A long time ago in a galaxy far, far away...
# vote_average                                                        8.1
# vote_count                                                         6624
# cast                        [Mark Hamill, Harrison Ford, Carrie Fisher]
# crew                         [George Lucas, George Lucas, George Lucas]
#
#                                                                       2
# budget                                                         94000000
# genres                                              [Animation, Family]
# homepage                          http://movies.disney.com/finding-nemo
# id                                                                   12
# keywords                  [father son relationship, harbor, underwater]
# original_language                                                    en
# title                                                      Finding Nemo
# overview              [Nemo, an adventurous young clownfish, is unex...
# popularity                                                    85.688789
# production_companies                          [Pixar Animation Studios]
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2003-05-30
# revenue                                                       940335536
# runtime                                                           100.0
# spoken_languages                                              [English]
# status                                                         Released
# tagline               There are 3.7 trillion fish in the ocean, they...
# vote_average                                                        7.6
# vote_count                                                         6122
# cast                  [Albert Brooks, Ellen DeGeneres, Alexander Gould]
# crew                   [Andrew Stanton, Andrew Stanton, Andrew Stanton]

# %% [markdown]
# #### 2.1.3 Combine and encode features

# %%
encoded_data_df["tags"]=encoded_data_df["overview"] + encoded_data_df["cast"] + encoded_data_df["genres"] + encoded_data_df["keywords"] 
encoded_data_df["tags"]=encoded_data_df["tags"].apply(lambda x: ', '.join(x))
encoded_data_df["tags"][0]
# Out:
# "It's Ted the Bellhop's first night on the job...and the hotel's very unusual guests are about to place him in some outrageous predicaments. It seems that this evening's room service is serving up one unbelievable happening after another., Tim Roth, Antonio Banderas, Jennifer Beals, Crime, Comedy, hotel, new year's eve, witch"

# %% [markdown]
# ### 2.2 Feature selection

# %%
tags = encoded_data_df["tags"]
print(tags[0])
# Out:
# It's Ted the Bellhop's first night on the job...and the hotel's very unusual guests are about to place him in some outrageous predicaments. It seems that this evening's room service is serving up one unbelievable happening after another., Tim Roth, Antonio Banderas, Jennifer Beals, Crime, Comedy, hotel, new year's eve, witch

# %% [markdown]
# ## 3. Model Training

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

vectorizer=TfidfVectorizer()
tfidf_matrix=vectorizer.fit_transform(tags)
print(tfidf_matrix[0])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 48 stored elements and shape (1, 25748)>
#   Coords	Values
#   (0, 12096)	0.1565104009948833
#   (0, 22880)	0.18588996900413085
#   (0, 23051)	0.09346761493199393
#   (0, 2386)	0.23878809842980947
#   (0, 8756)	0.1092159946038139
#   (0, 16094)	0.11916095725422207
#   (0, 16517)	0.05598935047287782
#   (0, 12368)	0.12469026510440573
#   (0, 1118)	0.03517877443636785
#   (0, 11105)	0.2850594717632179
#   (0, 24499)	0.12840795574863212
#   (0, 24212)	0.1723946991034821
#   (0, 10123)	0.18790453946328864
#   (0, 1398)	0.0768830607479857
#   (0, 403)	0.09643929326308162
#   (0, 23296)	0.03459285168233992
#   (0, 17586)	0.13271585486253826
#   (0, 10836)	0.07977852678403118
#   (0, 11541)	0.04114055815170533
#   (0, 21485)	0.12000788746746673
#   (0, 16744)	0.17905817198606314
#   (0, 17950)	0.22776582909393336
#   (0, 20495)	0.13530679166880422
#   (0, 23048)	0.06195349104052079
#   (0, 23122)	0.0907812179692401
#   (0, 8024)	0.18401444877667442
#   (0, 19756)	0.15947065723388304
#   (0, 20623)	0.15355200521748502
#   (0, 12059)	0.048901164395275594
#   (0, 20628)	0.18226001677181825
#   (0, 24227)	0.08249509875800476
#   (0, 16519)	0.08143390777135116
#   (0, 23941)	0.2138794119985476
#   (0, 10377)	0.19503671811255052
#   (0, 702)	0.07962229496880045
#   (0, 1217)	0.12616004256038454
#   (0, 23251)	0.14500273644638162
#   (0, 19803)	0.19008044132193921
#   (0, 1258)	0.16906184557729156
#   (0, 2013)	0.17619402422655345
#   (0, 12272)	0.12531046526003267
#   (0, 2227)	0.22776582909393336
#   (0, 5486)	0.0804125907714298
#   (0, 4776)	0.055761729732479094
#   (0, 16028)	0.07818122967349675
#   (0, 25528)	0.1028508916406651
#   (0, 8020)	0.15355200521748502
#   (0, 25273)	0.15296737492107282

# %%
model=NearestNeighbors(n_neighbors=5, algorithm="brute", metric="cosine")
fit_result=model.fit(tfidf_matrix)

# %% [markdown]
# ## 4. Movie recommender function

# %%
def get_movie_recommendations(movie_title):
  
    movie_index = encoded_data_df[encoded_data_df["title"] == movie_title].index[0]

    distances, indices = model.kneighbors(tfidf_matrix[movie_index])
   
    similar_movies = [(encoded_data_df["title"][i], distances[0][j]) for j, i in enumerate(indices[0])]
    
    return similar_movies[1:]

# %%
input_movie = "How to Train Your Dragon"
recommendations = get_movie_recommendations(input_movie)
print("Film recommendations '{}'".format(input_movie))
for movie, distance in recommendations:
    print("- Film: {}".format(movie))
# Out:
# Film recommendations 'How to Train Your Dragon'
# - Film: How to Train Your Dragon 2
# - Film: Dragon Nest: Warriors' Dawn
# - Film: Pete's Dragon
# - Film: Eragon

# %% [markdown]
# ## 5. Model Deployment

# %%
import pickle

# Save the assets
pickle.dump(model, open("../models/model.pkl", "wb"))
pickle.dump(tfidf_matrix, open("../data/tfidf_matrix.pkl", "wb"))
pickle.dump(encoded_data_df, open("../data/encoded_features_df.pkl", "wb"))
